# %% [markdown]
# # New LSTM Bergen PM2.5

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, KFold, RandomizedSearchCV
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from scikeras.wrappers import KerasRegressor
from kerastuner import HyperModel, RandomSearch
from tensorflow.keras import layers

# Load data
df = pd.read_excel("PM25Bergen.xlsx")  
 

# Temporal feature processing
# For example, convert time features to date time format and extract year, month, and day information
df['Time'] = pd.to_datetime(df['Time'], format='%d.%m.%Y')
df['Year'] = df['Time'].dt.year
df['Month'] = df['Time'].dt.month
df['Day'] = df['Time'].dt.day
df = df.sort_values(by='Time')  # Sort DataFrame by time
 
print(df.head(10))

# Extract features and target variable
X = df[["TV", "Tmean", "HDD", "VP", "WS", "WG", "meanRH", "SD", "PP", "Year", "Month","Day"]]
y = df["PM25"]


# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Define time steps
time_steps = 1  # You can adjust this as needed

# Generate time series data
X_time_series = []
y_time_series = []

for i in range(len(X_scaled) - time_steps):
    X_time_series.append(X_scaled[i:(i + time_steps), :])
    y_time_series.append(y[i + time_steps - 1])

X_time_series = np.concatenate(X_time_series, axis=0)
y_time_series = np.array(y_time_series)

# Data splitting
X_train, X_test, y_train, y_test = train_test_split(X_time_series, y_time_series, test_size=0.2, random_state=42)

# Define LSTM model
class MyHyperModel(HyperModel):
    def __init__(self, input_shape):
        self.input_shape = input_shape

    def build(self, hp):
        model = tf.keras.Sequential()
        model.add(tf.keras.layers.LSTM(units=hp.Int('units', min_value=32, max_value=512, step=16),
                                       activation='relu',
                                       return_sequences=True,
                                       kernel_regularizer=tf.keras.regularizers.l2(0.001),
                                       input_shape=self.input_shape))
        model.add(tf.keras.layers.Dropout(rate=hp.Choice('dropout_rate', values=[0.2, 0.4, 0.6, 0.8])))

        for i in range(hp.Int('num_layers', 1, 4)):
            model.add(tf.keras.layers.LSTM(units=hp.Int(f'units_{i}', min_value=32, max_value=512, step=16),
                                           activation='relu',
                                           return_sequences=True))
            model.add(tf.keras.layers.Dropout(rate=hp.Choice(f'dropout_rate_{i}', values=[0.2, 0.4, 0.6, 0.8])))

        model.add(tf.keras.layers.LSTM(units=hp.Int('units_last', min_value=32, max_value=512, step=16),
                                       activation='relu',
                                       kernel_regularizer=tf.keras.regularizers.l2(0.001)))
        model.add(tf.keras.layers.Dropout(rate=hp.Choice('dropout_rate_last', values=[0.2, 0.4, 0.6, 0.8])))

        model.add(tf.keras.layers.Dense(1))
        
        model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])),
                      loss='mse')
        return model

# Perform hyperparameter tuning
hypermodel = MyHyperModel(input_shape=(1, X_train.shape[1]))
tuner = RandomSearch(
    hypermodel,
    objective='val_loss',
    max_trials=10,
    executions_per_trial=2,
    directory='my_dir',
    project_name='PM25_prediction')

tuner.search(X_train.reshape((-1, 1, X_train.shape[1])), y_train, epochs=50, validation_split=0.2)

# Get best hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
# Out:
# Reloading Tuner from my_dir\PM25_prediction\tuner0.json

# %%
# Build final model with best hyperparameters
final_model = tuner.hypermodel.build(best_hps)

# Train the model
history = final_model.fit(X_train.reshape((-1, 1, X_train.shape[1])), y_train, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 12s 41ms/step - loss: 1.5500 - val_loss: 1.1292
# Epoch 2/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.3955 - val_loss: 1.0918
# Epoch 3/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3017 - val_loss: 1.0598
# Epoch 4/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.4976 - val_loss: 1.0311
# Epoch 5/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.4997 - val_loss: 1.0022
# Epoch 6/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.3733 - val_loss: 0.9669
# Epoch 7/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.3407 - val_loss: 0.9168
# Epoch 8/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.0908 - val_loss: 0.8617
# Epoch 9/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.2113 - val_loss: 0.8392
# Epoch 10/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.0742 - val_loss: 0.8257
# Epoch 11/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.3218 - val_loss: 0.8088
# Epoch 12/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.0277 - val_loss: 0.7996
# Epoch 13/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.8218 - val_loss: 0.7933
# Epoch 14/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 1.0576 - val_loss: 0.7882
# Epoch 15/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.8616 - val_loss: 0.7834
# Epoch 16/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.0205 - val_loss: 0.7813
# Epoch 17/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.9546 - val_loss: 0.7797
# Epoch 18/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.8765 - val_loss: 0.7745
# Epoch 19/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.8297 - val_loss: 0.7713
# Epoch 20/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.9622 - val_loss: 0.7704
# Epoch 21/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.9793 - val_loss: 0.7693
# Epoch 22/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.7337 - val_loss: 0.7670
# Epoch 23/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.8977 - val_loss: 0.7677
# Epoch 24/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.9170 - val_loss: 0.7637
# Epoch 25/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.8077 - val_loss: 0.7612
# Epoch 26/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9267 - val_loss: 0.7601
# Epoch 27/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.8354 - val_loss: 0.7593
# Epoch 28/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.7871 - val_loss: 0.7585
# Epoch 29/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.7827 - val_loss: 0.7693
# Epoch 30/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.7601 - val_loss: 0.7588
# Epoch 31/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.8256 - val_loss: 0.7554
# Epoch 32/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.8754 - val_loss: 0.7604
# Epoch 33/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9482 - val_loss: 0.7542
# Epoch 34/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.8402 - val_loss: 0.7531
# Epoch 35/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.0968 - val_loss: 0.7540
# Epoch 36/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.8060 - val_loss: 0.7519
# Epoch 37/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9080 - val_loss: 0.7513
# Epoch 38/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9738 - val_loss: 0.7514
# Epoch 39/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.6389 - val_loss: 0.7490
# Epoch 40/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.9803 - val_loss: 0.7487
# Epoch 41/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.7818 - val_loss: 0.7481
# Epoch 42/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.9723 - val_loss: 0.7478
# Epoch 43/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.9089 - val_loss: 0.7524
# Epoch 44/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.8246 - val_loss: 0.7452
# Epoch 45/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.9033 - val_loss: 0.7443
# Epoch 46/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.7147 - val_loss: 0.7446
# Epoch 47/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.9749 - val_loss: 0.7448
# Epoch 48/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9175 - val_loss: 0.7438
# Epoch 49/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.9059 - val_loss: 0.7433
# Epoch 50/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.8045 - val_loss: 0.7439

# %%
# Get best hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

# List optimal hyperparameters
print("Optimal Hyperparameters:")
print(f"units: {best_hps.get('units')}")
print(f"dropout_rate: {best_hps.get('dropout_rate')}")
print(f"num_layers: {best_hps.get('num_layers')}")

for i in range(best_hps.get('num_layers')):
    print(f"units_{i}: {best_hps.get(f'units_{i}')}")
    print(f"dropout_rate_{i}: {best_hps.get(f'dropout_rate_{i}')}")

print(f"units_last: {best_hps.get('units_last')}")
print(f"dropout_rate_last: {best_hps.get('dropout_rate_last')}")
print(f"learning_rate: {best_hps.get('learning_rate')}")
# Out:
# Optimal Hyperparameters:
# units: 320
# dropout_rate: 0.4
# num_layers: 1
# units_0: 272
# dropout_rate_0: 0.4
# units_last: 48
# dropout_rate_last: 0.8
# learning_rate: 0.0001

# %%
# Calculate RMSE
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 0.746

# %%
# Visualize the loss
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.title('The loss curves of the LSTM for the training set and the test set (The PM2.5 levels in Bergen)')
plt.xlabel('Epoch', fontweight='bold')
plt.ylabel('Loss', style='italic', loc='bottom')
plt.legend()
plt.show()

# %%
# Plot predicted vs. actual values
y_pred = final_model.predict(X_test.reshape((-1, 1, X_test.shape[1])))
plt.plot(y_test, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.xlabel('Samples')
plt.ylabel('PM2.5 Levels')
plt.title('Actual vs Predicted Bergen PM2.5 Levels based on LSTM')
plt.legend()
plt.show()
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step

# %%
import sys
print(sys.version)
# Out:
# 3.11.5 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:26:23) [MSC v.1916 64 bit (AMD64)]

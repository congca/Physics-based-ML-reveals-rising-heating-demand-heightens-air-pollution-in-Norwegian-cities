# %% [markdown]
# # New LSTM Trondheim NOX

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
#Read Excel file
df = pd.read_excel("NOxTrondheimTS.xlsx")

 
# Temporal feature processing
# For example, convert time features to date time format and extract year, month, and day information
df['Time'] = pd.to_datetime(df['Time'], format='%d.%m.%Y')
df['Year'] = df['Time'].dt.year
df['Month'] = df['Time'].dt.month
df['Day'] = df['Time'].dt.day
df = df.sort_values(by='Time')  # Sort DataFrame by time


#Extract features and target variables
X = df[["TV", "Tmean", "HDD", "VP", "WS", "WG", "meanRH", "SD", "PP", "Year", "Month","Day"]]
y = df["NOx"]

# Standardized features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)


import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

 

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Define time steps
time_steps = 1  # You can adjust this as needed

# Generate time series data
X_time_series = []
y_time_series = []

for i in range(len(X_scaled) - time_steps):
    X_time_series.append(X_scaled[i:(i + time_steps), :])
    y_time_series.append(y[i + time_steps - 1])

X_time_series = np.concatenate(X_time_series, axis=0)
y_time_series = np.array(y_time_series)

# Data splitting
X_train, X_test, y_train, y_test = train_test_split(X_time_series, y_time_series, test_size=0.2, random_state=42)

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras import regularizers
from kerastuner import HyperModel

# Define LSTM model
class MyHyperModel(HyperModel):
    def __init__(self, input_shape):
        self.input_shape = input_shape

    def build(self, hp):
        model = tf.keras.Sequential()
        model.add(tf.keras.layers.LSTM(units=hp.Int('units', min_value=32, max_value=512, step=16),
                                       activation='relu',
                                       return_sequences=True,
                                       kernel_regularizer=tf.keras.regularizers.l2(0.001),
                                       input_shape=self.input_shape))
        model.add(tf.keras.layers.Dropout(rate=hp.Choice('dropout_rate', values=[0.2, 0.4, 0.6, 0.8])))

        for i in range(hp.Int('num_layers', 1, 4)):
            model.add(tf.keras.layers.LSTM(units=hp.Int(f'units_{i}', min_value=32, max_value=512, step=16),
                                           activation='relu',
                                           return_sequences=True))
            model.add(tf.keras.layers.Dropout(rate=hp.Choice(f'dropout_rate_{i}', values=[0.2, 0.4, 0.6, 0.8])))

        model.add(tf.keras.layers.LSTM(units=hp.Int('units_last', min_value=32, max_value=512, step=16),
                                       activation='relu',
                                       kernel_regularizer=tf.keras.regularizers.l2(0.001)))
        model.add(tf.keras.layers.Dropout(rate=hp.Choice('dropout_rate_last', values=[0.2, 0.4, 0.6, 0.8])))

        model.add(tf.keras.layers.Dense(1))
        
        model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])),
                      loss='mse')
        return model
    
    

# Perform hyperparameter tuning
hypermodel = MyHyperModel(input_shape=(1, X_train.shape[1]))
tuner = RandomSearch(
    hypermodel,
    objective='val_loss',
    max_trials=10,
    executions_per_trial=2,
    directory='my_dir',
    project_name='NOx_prediction')

tuner.search(X_train.reshape((-1, 1, X_train.shape[1])), y_train, epochs=50, validation_split=0.2)

# Get best hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

# Build final model with best hyperparameters
final_model = tuner.hypermodel.build(best_hps)

# Train the model
history = final_model.fit(X_train.reshape((-1, 1, X_train.shape[1])), y_train, epochs=50, validation_split=0.2)
# Out:
# Reloading Tuner from my_dir\NOx_prediction\tuner0.json
# C:\Users\congc\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 0.4199 - val_loss: 0.2237
# Epoch 2/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1896 - val_loss: 0.1895
# Epoch 3/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1976 - val_loss: 0.1847
# Epoch 4/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1710 - val_loss: 0.1816
# Epoch 5/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.1767 - val_loss: 0.1764
# Epoch 6/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1794 - val_loss: 0.1860
# Epoch 7/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.1638 - val_loss: 0.1814
# Epoch 8/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.1813 - val_loss: 0.1789
# Epoch 9/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1725 - val_loss: 0.1781
# Epoch 10/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1766 - val_loss: 0.1761
# Epoch 11/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.1943 - val_loss: 0.1805
# Epoch 12/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1671 - val_loss: 0.1748
# Epoch 13/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1849 - val_loss: 0.1758
# Epoch 14/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1737 - val_loss: 0.1795
# Epoch 15/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1840 - val_loss: 0.1746
# Epoch 16/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1881 - val_loss: 0.1759
# Epoch 17/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1680 - val_loss: 0.1741
# Epoch 18/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.1935 - val_loss: 0.1751
# Epoch 19/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1852 - val_loss: 0.1739
# Epoch 20/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1850 - val_loss: 0.1742
# Epoch 21/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.1723 - val_loss: 0.1737
# Epoch 22/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 0.1860 - val_loss: 0.1695
# Epoch 23/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 0.1629 - val_loss: 0.1783
# Epoch 24/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.1974 - val_loss: 0.1750
# Epoch 25/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.1658 - val_loss: 0.1754
# Epoch 26/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1697 - val_loss: 0.1730
# Epoch 27/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.1800 - val_loss: 0.1773
# Epoch 28/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.1926 - val_loss: 0.1758
# Epoch 29/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1624 - val_loss: 0.1749
# Epoch 30/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.1572 - val_loss: 0.1764
# Epoch 31/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.1855 - val_loss: 0.1742
# Epoch 32/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.1628 - val_loss: 0.1769
# Epoch 33/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.1802 - val_loss: 0.1776
# Epoch 34/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.1782 - val_loss: 0.1749
# Epoch 35/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.1769 - val_loss: 0.1765
# Epoch 36/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.1608 - val_loss: 0.1751
# Epoch 37/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.1799 - val_loss: 0.1761
# Epoch 38/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 0.1836 - val_loss: 0.1785
# Epoch 39/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.1789 - val_loss: 0.1758
# Epoch 40/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.1677 - val_loss: 0.1796
# Epoch 41/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.1783 - val_loss: 0.1773
# Epoch 42/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 0.1756 - val_loss: 0.1777
# Epoch 43/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - loss: 0.1608 - val_loss: 0.1785
# Epoch 44/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 0.1635 - val_loss: 0.1797
# Epoch 45/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 0.1526 - val_loss: 0.1766
# Epoch 46/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 0.1887 - val_loss: 0.1731
# Epoch 47/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 0.1718 - val_loss: 0.1769
# Epoch 48/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 0.1555 - val_loss: 0.1769
# Epoch 49/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 0.1759 - val_loss: 0.1763
# Epoch 50/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 0.1689 - val_loss: 0.1762

# %%
# Plot predicted vs. actual values
plt.plot(y_test, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.xlabel('Samples')
plt.ylabel('NOx Levels')
plt.title('Actual vs Predicted Trondheim NOx Levels based on LSTM')
plt.legend()
plt.show()
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step

# %%
# Visualize the loss
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.title('The loss curves of the LSTM for the training set and the test set (The NOx levels in Trondheim)')
plt.xlabel('Epoch', fontweight='bold')
plt.ylabel('Loss', style='italic', loc='bottom')
plt.legend()
plt.show()

# %%
# Calculate RMSE
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 0.443

# %%
# Get best hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

# List optimal hyperparameters
print("Optimal Hyperparameters:")
print(f"units: {best_hps.get('units')}")
print(f"dropout_rate: {best_hps.get('dropout_rate')}")
print(f"num_layers: {best_hps.get('num_layers')}")

for i in range(best_hps.get('num_layers')):
    print(f"units_{i}: {best_hps.get(f'units_{i}')}")
    print(f"dropout_rate_{i}: {best_hps.get(f'dropout_rate_{i}')}")

print(f"units_last: {best_hps.get('units_last')}")
print(f"dropout_rate_last: {best_hps.get('dropout_rate_last')}")
print(f"learning_rate: {best_hps.get('learning_rate')}")
# Out:
# Optimal Hyperparameters:
# units: 272
# dropout_rate: 0.4
# num_layers: 3
# units_0: 496
# dropout_rate_0: 0.2
# units_1: 432
# dropout_rate_1: 0.6
# units_2: 208
# dropout_rate_2: 0.2
# units_last: 144
# dropout_rate_last: 0.4
# learning_rate: 0.001

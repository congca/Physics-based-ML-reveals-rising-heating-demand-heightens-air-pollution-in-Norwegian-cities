# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, KFold, RandomizedSearchCV
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from scikeras.wrappers import KerasRegressor
from kerastuner import HyperModel, RandomSearch
from tensorflow.keras import layers

# Load data
df = pd.read_excel("NOxOSLOTS.xlsx")  

 
# Temporal feature processing
# For example, convert time features to date time format and extract year, month, and day information
df['Time'] = pd.to_datetime(df['Time'], format='%d.%m.%Y')
df['Year'] = df['Time'].dt.year
df['Month'] = df['Time'].dt.month
df['Day'] = df['Time'].dt.day
df = df.sort_values(by='Time')  # Sort DataFrame by time

 
print(df.head(10))

# Extract features and target variable
X = df[["TV", "Tmean", "HDD", "VP", "WS", "WG", "meanRH", "SD", "PP", "Year", "Month","Day"]]
y = df["NOx"]


# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Define time steps
time_steps = 1  # You can adjust this as needed

# Generate time series data
X_time_series = []
y_time_series = []

for i in range(len(X_scaled) - time_steps):
    X_time_series.append(X_scaled[i:(i + time_steps), :])
    y_time_series.append(y[i + time_steps - 1])

X_time_series = np.concatenate(X_time_series, axis=0)
y_time_series = np.array(y_time_series)

# Data splitting
X_train, X_test, y_train, y_test = train_test_split(X_time_series, y_time_series, test_size=0.2, random_state=42)

# Define LSTM model
class MyHyperModel(HyperModel):
    def __init__(self, input_shape):
        self.input_shape = input_shape

    def build(self, hp):
        model = tf.keras.Sequential()
        model.add(tf.keras.layers.LSTM(units=hp.Int('units', min_value=32, max_value=512, step=16),
                                       activation='relu',
                                       return_sequences=True,
                                       kernel_regularizer=tf.keras.regularizers.l2(0.001),
                                       input_shape=self.input_shape))
        model.add(tf.keras.layers.Dropout(rate=hp.Choice('dropout_rate', values=[0.2, 0.4, 0.6, 0.8])))

        for i in range(hp.Int('num_layers', 1, 4)):
            model.add(tf.keras.layers.LSTM(units=hp.Int(f'units_{i}', min_value=32, max_value=512, step=16),
                                           activation='relu',
                                           return_sequences=True))
            model.add(tf.keras.layers.Dropout(rate=hp.Choice(f'dropout_rate_{i}', values=[0.2, 0.4, 0.6, 0.8])))

        model.add(tf.keras.layers.LSTM(units=hp.Int('units_last', min_value=32, max_value=512, step=16),
                                       activation='relu',
                                       kernel_regularizer=tf.keras.regularizers.l2(0.001)))
        model.add(tf.keras.layers.Dropout(rate=hp.Choice('dropout_rate_last', values=[0.2, 0.4, 0.6, 0.8])))

        model.add(tf.keras.layers.Dense(1))
        
        model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])),
                      loss='mse')
        return model

# Perform hyperparameter tuning
hypermodel = MyHyperModel(input_shape=(1, X_train.shape[1]))
tuner = RandomSearch(
    hypermodel,
    objective='val_loss',
    max_trials=10,
    executions_per_trial=2,
    directory='my_dir',
    project_name='NOx_prediction')

tuner.search(X_train.reshape((-1, 1, X_train.shape[1])), y_train, epochs=50, validation_split=0.2)

# Get best hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

# Build final model with best hyperparameters
final_model = tuner.hypermodel.build(best_hps)

# Train the model
history = final_model.fit(X_train.reshape((-1, 1, X_train.shape[1])), y_train, epochs=50, validation_split=0.2)
# Out:
# Reloading Tuner from my_dir\NOx_prediction\tuner0.json
# C:\Users\congc\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 25s 77ms/step - loss: 1.0855 - val_loss: 0.6627
# Epoch 2/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.7666 - val_loss: 0.6021
# Epoch 3/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.7067 - val_loss: 0.5813
# Epoch 4/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.7200 - val_loss: 0.5936
# Epoch 5/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.6812 - val_loss: 0.5934
# Epoch 6/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.7609 - val_loss: 0.5752
# Epoch 7/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.7470 - val_loss: 0.5694
# Epoch 8/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 0.7412 - val_loss: 0.5748
# Epoch 9/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 4s 45ms/step - loss: 0.6268 - val_loss: 0.5877
# Epoch 10/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.6246 - val_loss: 0.6074
# Epoch 11/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.7002 - val_loss: 0.5789
# Epoch 12/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.6406 - val_loss: 0.5816
# Epoch 13/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 0.6271 - val_loss: 0.5750
# Epoch 14/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 0.6342 - val_loss: 0.5844
# Epoch 15/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - loss: 0.6440 - val_loss: 0.5730
# Epoch 16/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 4s 49ms/step - loss: 0.6024 - val_loss: 0.5712
# Epoch 17/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 0.6072 - val_loss: 0.5816
# Epoch 18/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 0.7061 - val_loss: 0.5755
# Epoch 19/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 0.6219 - val_loss: 0.5840
# Epoch 20/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - loss: 0.7003 - val_loss: 0.5914
# Epoch 21/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.6649 - val_loss: 0.5872
# Epoch 22/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.6298 - val_loss: 0.5722
# Epoch 23/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.6993 - val_loss: 0.5737
# Epoch 24/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.6924 - val_loss: 0.5794
# Epoch 25/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 0.7005 - val_loss: 0.5808
# Epoch 26/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.5796 - val_loss: 0.5758
# Epoch 27/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.6080 - val_loss: 0.5699
# Epoch 28/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.6323 - val_loss: 0.5746
# Epoch 29/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.7202 - val_loss: 0.5746
# Epoch 30/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.6358 - val_loss: 0.5814
# Epoch 31/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.6505 - val_loss: 0.5884
# Epoch 32/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.6225 - val_loss: 0.7054
# Epoch 33/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.7325 - val_loss: 0.5844
# Epoch 34/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.6898 - val_loss: 0.5785
# Epoch 35/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.6227 - val_loss: 0.5830
# Epoch 36/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.5698 - val_loss: 0.5858
# Epoch 37/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.5833 - val_loss: 0.5827
# Epoch 38/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.6135 - val_loss: 0.5896
# Epoch 39/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.6363 - val_loss: 0.5803
# Epoch 40/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.6339 - val_loss: 0.5893
# Epoch 41/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.6115 - val_loss: 0.5824
# Epoch 42/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.5803 - val_loss: 0.5813
# Epoch 43/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.6084 - val_loss: 0.5820
# Epoch 44/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.7046 - val_loss: 0.5875
# Epoch 45/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 0.6110 - val_loss: 0.6016
# Epoch 46/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.5817 - val_loss: 0.6055
# Epoch 47/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.6684 - val_loss: 0.5993
# Epoch 48/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.6226 - val_loss: 0.5878
# Epoch 49/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 0.6485 - val_loss: 0.5855
# Epoch 50/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 0.6067 - val_loss: 0.5941

# %%
# Get best hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

# List optimal hyperparameters
print("Optimal Hyperparameters:")
print(f"units: {best_hps.get('units')}")
print(f"dropout_rate: {best_hps.get('dropout_rate')}")
print(f"num_layers: {best_hps.get('num_layers')}")

for i in range(best_hps.get('num_layers')):
    print(f"units_{i}: {best_hps.get(f'units_{i}')}")
    print(f"dropout_rate_{i}: {best_hps.get(f'dropout_rate_{i}')}")

print(f"units_last: {best_hps.get('units_last')}")
print(f"dropout_rate_last: {best_hps.get('dropout_rate_last')}")
print(f"learning_rate: {best_hps.get('learning_rate')}")
# Out:
# Optimal Hyperparameters:
# units: 272
# dropout_rate: 0.4
# num_layers: 3
# units_0: 496
# dropout_rate_0: 0.2
# units_1: 432
# dropout_rate_1: 0.6
# units_2: 208
# dropout_rate_2: 0.2
# units_last: 144
# dropout_rate_last: 0.4
# learning_rate: 0.001

# %%
# Calculate RMSE
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 0.764

# %%
# Plot predicted vs. actual values
y_pred = final_model.predict(X_test.reshape((-1, 1, X_test.shape[1])))
plt.plot(y_test, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.xlabel('Samples')
plt.ylabel('NOx Levels')
plt.title('Actual vs Predicted Oslo NOx Levels based on LSTM')
plt.legend()
plt.show()
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step

# %%
# Visualize the loss
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.title('The loss curves of the LSTM for the training set and the test set (The NOx levels in Oslo)')
plt.xlabel('Epoch', fontweight='bold')
plt.ylabel('Loss', style='italic', loc='bottom')
plt.legend()
plt.show()

# %%
import sys
print(sys.version)
# Out:
# 3.11.5 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:26:23) [MSC v.1916 64 bit (AMD64)]

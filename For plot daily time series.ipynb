# %%
from sklearn.model_selection import KFold, GridSearchCV

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold
# Out:
# WARNING:tensorflow:From C:\Users\congc\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
df = pd.read_excel("for plot daily time series.xlsx")  
df.head()
# Out:
#   Time(norwegian mean time)  day  weekday  dayofmonth  monthoftheyear  year  \
# 0                01.01.2009    1        4           1               1  2009
# 1                02.01.2009    2        5           2               1  2009
# 2                03.01.2009    3        6           3               1  2009
# 3                04.01.2009    4        7           4               1  2009
# 4                05.01.2009    5        1           5               1  2009
#
#    Oslo NOx  Oslo PM25  Bergen PM25  Bergen NOx  Trondheim PM25  Trondheim NOx
# 0     195.0       67.0         13.0        67.0             5.0           26.0
# 1     196.0       21.0         19.0       199.0             3.0           27.0
# 2     142.0       17.0         17.0       156.0            12.0           79.0
# 3      99.0       20.0         27.0       150.0             9.0           25.0
# 4     427.0       37.0         23.0       364.0             4.0           46.0

# %%
values = df.values
# 指定要可视化的例
groups = [ 6, 7]
i = 1
# plot each column
plt.figure(figsize=(18,19))
for group in groups:
    plt.subplot(len(groups), 1, i)
    plt.plot(values[:, group])
    plt.title(df.columns[group], y=0.5, loc='right')
    plt.xlabel("Days",size=20)
    plt.ylabel("Air pollution value(µg/m³)",size=20)
    i += 1
plt.show()

# %%
values = df.values
# 指定要可视化的例
groups = [ 9,8 ]
i = 1
# plot each column
plt.figure(figsize=(18,19))
for group in groups:
    plt.subplot(len(groups), 1, i)
    plt.plot(values[:, group])
    plt.title(df.columns[group], y=0.5, loc='right')
    plt.xlabel("Days",size=20)
    plt.ylabel("Air pollution value(µg/m³)",size=20)
    i += 1
plt.show()

# %%
values = df.values
# 指定要可视化的例
groups = [ 11,10]
i = 1
# plot each column
plt.figure(figsize=(18,19))
for group in groups:
    plt.subplot(len(groups), 1, i)
    plt.plot(values[:, group])
    plt.title(df.columns[group], y=0.5, loc='right')
    plt.xlabel("Days",size=20)
    plt.ylabel("Air pollution value(µg/m³)",size=20)
    i += 1
plt.show()

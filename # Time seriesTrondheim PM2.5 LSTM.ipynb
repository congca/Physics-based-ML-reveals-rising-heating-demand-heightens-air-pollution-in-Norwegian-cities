# %% [markdown]
# # New LSTM Trondheim PM2.5

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, KFold, RandomizedSearchCV
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler
from scikeras.wrappers import KerasRegressor
from kerastuner import HyperModel, RandomSearch
from tensorflow.keras import layers

# Load data
df = pd.read_excel("PM25TrondheimTS.xlsx")  

 
# Temporal feature processing
# For example, convert time features to date time format and extract year, month, and day information

df['Time'] = pd.to_datetime(df['Time'], format='%d.%m.%Y')
df['Year'] = df['Time'].dt.year
df['Month'] = df['Time'].dt.month
df['Day'] = df['Time'].dt.day
df = df.sort_values(by='Time')  # Sort DataFrame by time

print(df.head(10))

# Extract features and target variable
X = df[["TV", "Tmean", "HDD", "VP", "WS", "WG", "meanRH", "SD", "PP", "Year", "Month","Day"]]
y = df["PM25"]


# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Define time steps
time_steps = 1  # You can adjust this as needed

# Generate time series data
X_time_series = []
y_time_series = []

for i in range(len(X_scaled) - time_steps):
    X_time_series.append(X_scaled[i:(i + time_steps), :])
    y_time_series.append(y[i + time_steps - 1])

X_time_series = np.concatenate(X_time_series, axis=0)
y_time_series = np.array(y_time_series)

# Data splitting
X_train, X_test, y_train, y_test = train_test_split(X_time_series, y_time_series, test_size=0.2, random_state=42)

# Define LSTM model
class MyHyperModel(HyperModel):
    def __init__(self, input_shape):
        self.input_shape = input_shape

    def build(self, hp):
        model = tf.keras.Sequential()
        model.add(tf.keras.layers.LSTM(units=hp.Int('units', min_value=32, max_value=512, step=16),
                                       activation='relu',
                                       return_sequences=True,
                                       kernel_regularizer=tf.keras.regularizers.l2(0.001),
                                       input_shape=self.input_shape))
        model.add(tf.keras.layers.Dropout(rate=hp.Choice('dropout_rate', values=[0.2, 0.4, 0.6, 0.8])))

        for i in range(hp.Int('num_layers', 1, 4)):
            model.add(tf.keras.layers.LSTM(units=hp.Int(f'units_{i}', min_value=32, max_value=512, step=16),
                                           activation='relu',
                                           return_sequences=True))
            model.add(tf.keras.layers.Dropout(rate=hp.Choice(f'dropout_rate_{i}', values=[0.2, 0.4, 0.6, 0.8])))

        model.add(tf.keras.layers.LSTM(units=hp.Int('units_last', min_value=32, max_value=512, step=16),
                                       activation='relu',
                                       kernel_regularizer=tf.keras.regularizers.l2(0.001)))
        model.add(tf.keras.layers.Dropout(rate=hp.Choice('dropout_rate_last', values=[0.2, 0.4, 0.6, 0.8])))

        model.add(tf.keras.layers.Dense(1))
        
        model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])),
                      loss='mse')
        return model

# Perform hyperparameter tuning
hypermodel = MyHyperModel(input_shape=(1, X_train.shape[1]))
tuner = RandomSearch(
    hypermodel,
    objective='val_loss',
    max_trials=10,
    executions_per_trial=2,
    directory='my_dir',
    project_name='PM25_prediction')

tuner.search(X_train.reshape((-1, 1, X_train.shape[1])), y_train, epochs=50, validation_split=0.2)

# Get best hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

# Build final model with best hyperparameters
final_model = tuner.hypermodel.build(best_hps)

# Train the model
history = final_model.fit(X_train.reshape((-1, 1, X_train.shape[1])), y_train, epochs=50, validation_split=0.2)
# Out:
# Reloading Tuner from my_dir\PM25_prediction\tuner0.json
# C:\Users\congc\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 1.3949 - val_loss: 1.5262
# Epoch 2/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1126 - val_loss: 1.4903
# Epoch 3/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0678 - val_loss: 1.4601
# Epoch 4/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9071 - val_loss: 1.4349
# Epoch 5/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0117 - val_loss: 1.4131
# Epoch 6/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9589 - val_loss: 1.3945
# Epoch 7/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9576 - val_loss: 1.3779
# Epoch 8/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9237 - val_loss: 1.3628
# Epoch 9/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9942 - val_loss: 1.3478
# Epoch 10/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8844 - val_loss: 1.3324
# Epoch 11/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9003 - val_loss: 1.3132
# Epoch 12/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9563 - val_loss: 1.2915
# Epoch 13/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0030 - val_loss: 1.2656
# Epoch 14/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9843 - val_loss: 1.2369
# Epoch 15/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8529 - val_loss: 1.2257
# Epoch 16/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9027 - val_loss: 1.2204
# Epoch 17/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8620 - val_loss: 1.2113
# Epoch 18/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8528 - val_loss: 1.2086
# Epoch 19/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8431 - val_loss: 1.2036
# Epoch 20/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7716 - val_loss: 1.2040
# Epoch 21/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8895 - val_loss: 1.1991
# Epoch 22/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8611 - val_loss: 1.2016
# Epoch 23/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7463 - val_loss: 1.1964
# Epoch 24/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0092 - val_loss: 1.1995
# Epoch 25/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9331 - val_loss: 1.1978
# Epoch 26/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0649 - val_loss: 1.1992
# Epoch 27/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8915 - val_loss: 1.1972
# Epoch 28/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1.2127 - val_loss: 1.1965
# Epoch 29/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8487 - val_loss: 1.1930
# Epoch 30/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7901 - val_loss: 1.1977
# Epoch 31/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8673 - val_loss: 1.1951
# Epoch 32/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9244 - val_loss: 1.1929
# Epoch 33/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9747 - val_loss: 1.2023
# Epoch 34/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9289 - val_loss: 1.1981
# Epoch 35/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9366 - val_loss: 1.1937
# Epoch 36/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0135 - val_loss: 1.1934
# Epoch 37/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9281 - val_loss: 1.1940
# Epoch 38/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8325 - val_loss: 1.1900
# Epoch 39/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8671 - val_loss: 1.1908
# Epoch 40/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9118 - val_loss: 1.1885
# Epoch 41/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1223 - val_loss: 1.1913
# Epoch 42/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7448 - val_loss: 1.1906
# Epoch 43/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9616 - val_loss: 1.1908
# Epoch 44/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8376 - val_loss: 1.1930
# Epoch 45/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8848 - val_loss: 1.1925
# Epoch 46/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9110 - val_loss: 1.1965
# Epoch 47/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0826 - val_loss: 1.1930
# Epoch 48/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9568 - val_loss: 1.1901
# Epoch 49/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1221 - val_loss: 1.1959
# Epoch 50/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7713 - val_loss: 1.1938

# %%
# Get best hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

# List optimal hyperparameters
print("Optimal Hyperparameters:")
print(f"units: {best_hps.get('units')}")
print(f"dropout_rate: {best_hps.get('dropout_rate')}")
print(f"num_layers: {best_hps.get('num_layers')}")

for i in range(best_hps.get('num_layers')):
    print(f"units_{i}: {best_hps.get(f'units_{i}')}")
    print(f"dropout_rate_{i}: {best_hps.get(f'dropout_rate_{i}')}")

print(f"units_last: {best_hps.get('units_last')}")
print(f"dropout_rate_last: {best_hps.get('dropout_rate_last')}")
print(f"learning_rate: {best_hps.get('learning_rate')}")
# Out:
# Optimal Hyperparameters:
# units: 320
# dropout_rate: 0.4
# num_layers: 1
# units_0: 272
# dropout_rate_0: 0.4
# units_last: 48
# dropout_rate_last: 0.8
# learning_rate: 0.0001

# %%
# Calculate RMSE
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 1.032

# %%
# Plot predicted vs. actual values
y_pred = final_model.predict(X_test.reshape((-1, 1, X_test.shape[1])))
plt.plot(y_test, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.xlabel('Samples')
plt.ylabel('PM2.5 Levels')
plt.title('Actual vs Predicted Trondheim PM2.5 Levels based on LSTM')
plt.legend()
plt.show()
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
# 对损失进行可视化
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.title('The loss curves of the LSTM for the training set and the test set (The PM2.5 levels in Trondheim)')
plt.xlabel('Epoch', fontweight='bold')
plt.ylabel('Loss', style='italic', loc='bottom')
plt.legend()
plt.show()

# %%
import sys
print(sys.version)
# Out:
# 3.11.5 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:26:23) [MSC v.1916 64 bit (AMD64)]

# %% [markdown]
# # New LSTM Bergen NOX

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from kerastuner import HyperModel, RandomSearch
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.inspection import permutation_importance
import matplotlib.pyplot as plt
from scipy import stats

# Load data
df = pd.read_excel("NOxBergen.xlsx")  

# Extract features and target variable
X = df[["TV", "Tmean", "HDD", "VP", "WS", "WG", "meanRH", "SD", "PP"]]
Y = df["NOx"]

# Standardize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

def create_sequences(data, target, time_steps, forecast_days):
    sequences = []
    targets = []
    for i in range(len(data) - time_steps - forecast_days + 1):
        sequences.append(data[i:i + time_steps])
        targets.append(target[i + time_steps:i + time_steps + forecast_days])
    return np.array(sequences), np.array(targets)

def plot_learning_curves(history):
    plt.figure(figsize=(12, 6))
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Learning Curves')
    plt.legend()
    plt.show()

# List of different time steps to test
time_steps_list = [1, 2, 3, 4, 5, 6, 7]
forecast_days_list = [7, 10]

# Dictionary to hold train and test data for each time step and forecast day,  with validation dateset
data_dict = {}

for time_steps in time_steps_list:
    for forecast_days in forecast_days_list:
        X_seq, y_seq = create_sequences(X_scaled, Y, time_steps, forecast_days)
        X_train_seq, X_temp_seq, y_train_seq, y_temp_seq = train_test_split(X_seq, y_seq, test_size=0.4, random_state=42)
        X_val_seq, X_test_seq, y_val_seq, y_test_seq = train_test_split(X_temp_seq, y_temp_seq, test_size=0.5, random_state=42)
        data_dict[(time_steps, forecast_days)] = (X_train_seq, X_val_seq, X_test_seq, y_train_seq, y_val_seq, y_test_seq)

class MyHyperModel(HyperModel):
    def __init__(self, input_shape, forecast_days):
        self.input_shape = input_shape
        self.forecast_days = forecast_days

    def build(self, hp):
        model = tf.keras.Sequential()
        model.add(layers.LSTM(units=hp.Int('units', min_value=32, max_value=512, step=16),
                              activation='relu',
                              return_sequences=True,
                              kernel_regularizer=tf.keras.regularizers.l2(0.001),
                              input_shape=self.input_shape))
        model.add(layers.Dropout(rate=hp.Choice('dropout_rate', values=[0.2, 0.4, 0.6, 0.8])))

        for i in range(hp.Int('num_layers', 1, 4)):
            model.add(layers.LSTM(units=hp.Int(f'units_{i}', min_value=32, max_value=512, step=16),
                                  activation='relu',
                                  return_sequences=True))
            model.add(layers.Dropout(rate=hp.Choice(f'dropout_rate_{i}', values=[0.2, 0.4, 0.6, 0.8])))

        model.add(layers.LSTM(units=hp.Int('units_last', min_value=32, max_value=512, step=16),
                              activation='relu',
                              kernel_regularizer=tf.keras.regularizers.l2(0.001)))
        model.add(layers.Dropout(rate=hp.Choice('dropout_rate_last', values=[0.2, 0.4, 0.6, 0.8])))

        model.add(layers.Dense(self.forecast_days))
        
        model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])),
                      loss='mse')
        return model

results = {}
history_dict = {}  # To store history for learning curves
# Out:
# Trial 5 Complete [00h 03m 56s]
# val_loss: 1.9567179083824158
#
# Best val_loss So Far: 0.6350095868110657
# Total elapsed time: 04h 08m 42s
#
# Search: Running Trial #6
#
# Value             |Best Value So Far |Hyperparameter
# 256               |192               |units
# 0.2               |0.2               |dropout_rate
# 2                 |2                 |num_layers
# 64                |96                |units_0
# 0.4               |0.4               |dropout_rate_0
# 256               |192               |units_last
# 0.4               |0.4               |dropout_rate_last
# 0.001             |0.001             |learning_rate
# 160               |32                |units_1
# 0.4               |0.2               |dropout_rate_1
#
# Epoch 1/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 35s 82ms/step - loss: 2.6705 - val_loss: 2.6065
# Epoch 2/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 2.0051 - val_loss: 2.2949
# Epoch 3/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 1.9854 - val_loss: 2.0470
# Epoch 4/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 1.8093 - val_loss: 2.1188
# Epoch 5/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 1.8854 - val_loss: 2.2445
# Epoch 6/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - loss: 1.8093 - val_loss: 1.8493
# Epoch 7/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - loss: 1.9109 - val_loss: 2.0091
# Epoch 8/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 1.8058 - val_loss: 2.0280
# Epoch 9/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - loss: 1.7555 - val_loss: 1.8463
# Epoch 10/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 51ms/step - loss: 1.5368 - val_loss: 1.9637
# Epoch 11/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 51ms/step - loss: 1.6349 - val_loss: 1.8522
# Epoch 12/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 1.8017 - val_loss: 1.7858
# Epoch 13/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 51ms/step - loss: 1.7160 - val_loss: 1.9806
# Epoch 14/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 51ms/step - loss: 1.7020 - val_loss: 1.8583
# Epoch 15/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 1.6858 - val_loss: 1.8472
# Epoch 16/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 1.8342 - val_loss: 2.0934
# Epoch 17/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 52ms/step - loss: 1.6957 - val_loss: 1.8847
# Epoch 18/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 51ms/step - loss: 1.5399 - val_loss: 1.9198
# Epoch 19/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - loss: 1.5802 - val_loss: 1.8445
# Epoch 20/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - loss: 1.6742 - val_loss: 1.8773
# Epoch 21/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 1.6130 - val_loss: 1.7838
# Epoch 22/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 51ms/step - loss: 1.5978 - val_loss: 2.0739
# Epoch 23/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - loss: 1.6548 - val_loss: 2.0481
# Epoch 24/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 1.5233 - val_loss: 1.7835
# Epoch 25/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 1.5520 - val_loss: 1.8443
# Epoch 26/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 1.5595 - val_loss: 1.9896
# Epoch 27/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 3s 45ms/step - loss: 1.6524 - val_loss: 2.0806
# Epoch 28/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 1.5100 - val_loss: 1.8778
# Epoch 29/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 1.4501 - val_loss: 1.8491
# Epoch 30/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 1.5696 - val_loss: 1.7465
# Epoch 31/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 1.5113 - val_loss: 1.8894
# Epoch 32/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 1.4315 - val_loss: 1.7475
# Epoch 33/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 1.5361 - val_loss: 2.0986
# Epoch 34/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 50ms/step - loss: 1.5416 - val_loss: 1.8865
# Epoch 35/50
# 14/69 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - loss: 1.4664
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 107
#      98 hypermodel = MyHyperModel(input_shape=input_shape, forecast_days=forecast_days)
#      99 tuner = RandomSearch(
#     100     hypermodel,
#     101     objective='val_loss',
#    (...)
#     104     directory=f'my_dir_{time_steps}_{forecast_days}',
#     105     project_name='NOx_prediction')
# --> 107 tuner.search(X_train_seq, y_train_seq, epochs=50, validation_data=(X_val_seq, y_val_seq))
#     109 # Get best hyperparameters
#     110 best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
#
# File ~\anaconda3\Lib\site-packages\keras_tuner\src\engine\base_tuner.py:234, in BaseTuner.search(self, *fit_args, **fit_kwargs)
#     231         continue
#     233     self.on_trial_begin(trial)
# --> 234     self._try_run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     235     self.on_trial_end(trial)
#     236 self.on_search_end()
#
# File ~\anaconda3\Lib\site-packages\keras_tuner\src\engine\base_tuner.py:274, in BaseTuner._try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     272 def _try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
#     273     try:
# --> 274         self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     275         trial.status = trial_module.TrialStatus.COMPLETED
#     276         return
#
# File ~\anaconda3\Lib\site-packages\keras_tuner\src\engine\base_tuner.py:239, in BaseTuner._run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     238 def _run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
# --> 239     results = self.run_trial(trial, *fit_args, **fit_kwargs)
#     240     if self.oracle.get_trial(trial.trial_id).metrics.exists(
#     241         self.oracle.objective.name
#     242     ):
#     243         # The oracle is updated by calling `self.oracle.update_trial()` in
#     244         # `Tuner.run_trial()`. For backward compatibility, we support this
#     245         # use case. No further action needed in this case.
#     246         warnings.warn(
#     247             "The use case of calling "
#     248             "`self.oracle.update_trial(trial_id, metrics)` "
#    (...)
#     254             stacklevel=2,
#     255         )
#
# File ~\anaconda3\Lib\site-packages\keras_tuner\src\engine\tuner.py:314, in Tuner.run_trial(self, trial, *args, **kwargs)
#     312     callbacks.append(model_checkpoint)
#     313     copied_kwargs["callbacks"] = callbacks
# --> 314     obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#     316     histories.append(obj_value)
#     317 return histories
#
# File ~\anaconda3\Lib\site-packages\keras_tuner\src\engine\tuner.py:233, in Tuner._build_and_fit_model(self, trial, *args, **kwargs)
#     231 hp = trial.hyperparameters
#     232 model = self._try_build(hp)
# --> 233 results = self.hypermodel.fit(hp, model, *args, **kwargs)
#     235 # Save the build config for model loading later.
#     236 if backend.config.multi_backend():
#
# File ~\anaconda3\Lib\site-packages\keras_tuner\src\engine\hypermodel.py:149, in HyperModel.fit(self, hp, model, *args, **kwargs)
#     125 def fit(self, hp, model, *args, **kwargs):
#     126     """Train the model.
#     127
#     128     Args:
#    (...)
#     147         If return a float, it should be the `objective` value.
#     148     """
# --> 149     return model.fit(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:118, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     116 filtered_tb = None
#     117 try:
# --> 118     return fn(*args, **kwargs)
#     119 except Exception as e:
#     120     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:323, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     321 for step, iterator in epoch_iterator.enumerate_epoch():
#     322     callbacks.on_train_batch_begin(step)
# --> 323     logs = self.train_function(iterator)
#     324     callbacks.on_train_batch_end(
#     325         step, self._pythonify_logs(logs)
#     326     )
#     327     if self.stop_training:
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\context.py:1500, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1498 cancellation_context = cancellation.context()
#    1499 if cancellation_context is None:
# -> 1500   outputs = execute.execute(
#    1501       name.decode("utf-8"),
#    1502       num_outputs=num_outputs,
#    1503       inputs=tensor_inputs,
#    1504       attrs=attrs,
#    1505       ctx=self,
#    1506   )
#    1507 else:
#    1508   outputs = execute.execute_with_cancellation(
#    1509       name.decode("utf-8"),
#    1510       num_outputs=num_outputs,
#    (...)
#    1514       cancellation_manager=cancellation_context,
#    1515   )
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
for time_steps in time_steps_list:
    for forecast_days in forecast_days_list:
        X_train_seq, X_val_seq, X_test_seq, y_train_seq, y_val_seq, y_test_seq = data_dict[(time_steps, forecast_days)]
        input_shape = (time_steps, X_train_seq.shape[2])

        # Define and tune the model
        hypermodel = MyHyperModel(input_shape=input_shape, forecast_days=forecast_days)
        tuner = RandomSearch(
            hypermodel,
            objective='val_loss',
            max_trials=1,
            executions_per_trial=2,
            directory=f'my_dir_{time_steps}_{forecast_days}',
            project_name='NOx_prediction')

        tuner.search(X_train_seq, y_train_seq, epochs=50, validation_data=(X_val_seq, y_val_seq))
        
        # Get best hyperparameters
        best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
        
        # Build final model with best hyperparameters
        final_model = tuner.hypermodel.build(best_hps)
        
        # Train the model
        history = final_model.fit(X_train_seq, y_train_seq, epochs=50, validation_data=(X_val_seq, y_val_seq), verbose=1)
        history_dict[(time_steps, forecast_days)] = history
        
 
        
        # Evaluate the model
        y_pred = final_model.predict(X_test_seq)
        test_loss = final_model.evaluate(X_test_seq, y_test_seq, verbose=0)
        
        # Additional evaluation metrics
        test_mae = mean_absolute_error(y_test_seq, y_pred)
        test_rmse = np.sqrt(mean_squared_error(y_test_seq, y_pred))
        
        results[(time_steps, forecast_days)] = {
            'loss': test_loss,
            'mae': test_mae,
            'rmse': test_rmse
        }

# Print results for LSTM models
print("LSTM Model Results:")
for (time_steps, forecast_days), metrics in results.items():
    print(f"Time steps: {time_steps}, Forecast days: {forecast_days}")
    print(f"Test Loss: {metrics['loss']}")
    print(f"Test MAE: {metrics['mae']}")
    print(f"Test RMSE: {metrics['rmse']}")
    print("")

# Train and evaluate a Linear Regression model
print("Linear Regression Model Results:")

# Flatten data for linear regression
X_flat = X_scaled[time_steps_list[0] - 1:]  # Use the data for the minimum time_steps
Y_flat = Y[time_steps_list[0] - 1:]  # Corresponding target variable
X_train_flat, X_temp_flat, y_train_flat, y_temp_flat = train_test_split(X_flat, Y_flat, test_size=0.4, random_state=42)
X_val_flat, X_test_flat, y_val_flat, y_test_flat = train_test_split(X_temp_flat, y_temp_flat, test_size=0.5, random_state=42)

# Train Linear Regression model
lin_reg = LinearRegression()
lin_reg.fit(X_train_flat, y_train_flat)

# Predict and evaluate
y_pred_lin = lin_reg.predict(X_test_flat)
lin_test_mae = mean_absolute_error(y_test_flat, y_pred_lin)
lin_test_rmse = np.sqrt(mean_squared_error(y_test_flat, y_pred_lin))

print(f"Test MAE: {lin_test_mae}")
print(f"Test RMSE: {lin_test_rmse}")
print("")

# Feature importance analysis using permutation importance
print("Feature Importance Analysis:")
model_rf = RandomForestRegressor(n_estimators=100, random_state=42)
model_rf.fit(X_flat, Y_flat)
result = permutation_importance(model_rf, X_flat, Y_flat, n_repeats=10, random_state=42, scoring='neg_mean_squared_error')

for i in result.importances_mean.argsort()[::-1]:
    print(f"Feature: {X.columns[i]}, Importance: {result.importances_mean[i]}")

# Statistical hypothesis testing

# Extract the LSTM results for T-Test
lstm_losses = np.array([metrics['loss'] for metrics in results.values()])

# comparing two groups
group1_losses = lstm_losses[:len(lstm_losses)//2]  # First half of the results
group2_losses = lstm_losses[len(lstm_losses)//2:]  # Second half of the results

# Perform independent T-Test
t_stat, p_value = stats.ttest_ind(group1_losses, group2_losses)
print("Independent T-Test Results")
print("T-Statistic:", t_stat)
print("P-Value:", p_value)

# Perform ANOVA
# For simplicity, using all LSTM results as different groups
f_stat, p_value_anova = stats.f_oneway(*[lstm_losses[i:i+len(lstm_losses)//len(time_steps_list)] for i in range(0, len(lstm_losses), len(lstm_losses)//len(time_steps_list))])
print("ANOVA Test Results")
print("F-Statistic:", f_stat)
print("P-Value:", p_value_anova)

# Policy Recommendations
print("\nPolicy Recommendations:")

# If LSTM models perform better than Linear Regression (based on lower MAE and RMSE)
if np.mean([metrics['rmse'] for metrics in results.values()]) < lin_test_rmse:
    print("1. The LSTM models outperform the Linear Regression model in terms of prediction accuracy. Policies should consider using advanced models like LSTM for better air quality forecasting.")

# Based on feature importance
important_features = [X.columns[i] for i in result.importances_mean.argsort()[::-1]]
print("2. Based on feature importance, focus on improving conditions related to the most important features:")
for feature in important_features[:5]:  # Top 5 features
    print(f"- {feature}: Implement measures to reduce or control the impact of {feature}.")

# General recommendations based on evaluation metrics
if np.mean([metrics['mae'] for metrics in results.values()]) < lin_test_mae:
    print("3. Consider implementing policies that address the factors contributing to NOx emissions, as indicated by the features with high importance scores, to reduce overall pollution levels.")
else:
    print("4. Continue monitoring and refining models to achieve better predictive performance, which can guide more effective policy interventions.")
# Out:
# Reloading Tuner from my_dir_1_7\NOx_prediction\tuner0.json
# Epoch 1/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - loss: 2.0682 - val_loss: 1.7764
# Epoch 2/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.9136 - val_loss: 1.7676
# Epoch 3/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.7474 - val_loss: 1.7160
# Epoch 4/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6711 - val_loss: 1.7196
# Epoch 5/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.7793 - val_loss: 1.7495
# Epoch 6/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6236 - val_loss: 1.7122
# Epoch 7/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.5956 - val_loss: 1.6716
# Epoch 8/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6036 - val_loss: 1.6787
# Epoch 9/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.5012 - val_loss: 1.7083
# Epoch 10/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.5049 - val_loss: 1.7387
# Epoch 11/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6452 - val_loss: 1.7455
# Epoch 12/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.5585 - val_loss: 1.7081
# Epoch 13/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6155 - val_loss: 1.7332
# Epoch 14/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.4547 - val_loss: 1.7246
# Epoch 15/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.5874 - val_loss: 1.7302
# Epoch 16/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.5220 - val_loss: 1.7215
# Epoch 17/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.5064 - val_loss: 1.7171
# Epoch 18/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.4903 - val_loss: 1.7384
# Epoch 19/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.4997 - val_loss: 1.7330
# Epoch 20/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.4775 - val_loss: 1.7314
# Epoch 21/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.3211 - val_loss: 1.7267
# Epoch 22/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.5868 - val_loss: 1.7514
# Epoch 23/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.3655 - val_loss: 1.7530
# Epoch 24/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.4397 - val_loss: 1.7139
# Epoch 25/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.3877 - val_loss: 1.7572
# Epoch 26/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.4636 - val_loss: 1.7156
# Epoch 27/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.4136 - val_loss: 1.7386
# Epoch 28/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.4138 - val_loss: 1.7477
# Epoch 29/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.3348 - val_loss: 1.8420
# Epoch 30/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.3994 - val_loss: 1.7385
# Epoch 31/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.3826 - val_loss: 1.7948
# Epoch 32/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.2925 - val_loss: 1.7971
# Epoch 33/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.2883 - val_loss: 1.8071
# Epoch 34/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.3392 - val_loss: 1.7952
# Epoch 35/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.3616 - val_loss: 1.8068
# Epoch 36/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.2668 - val_loss: 1.8424
# Epoch 37/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.2670 - val_loss: 1.8316
# Epoch 38/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.1891 - val_loss: 1.8858
# Epoch 39/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.2228 - val_loss: 1.8249
# Epoch 40/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.1492 - val_loss: 1.8761
# Epoch 41/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.2190 - val_loss: 1.8871
# Epoch 42/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.1383 - val_loss: 1.8723
# Epoch 43/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.2778 - val_loss: 1.8567
# Epoch 44/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.2351 - val_loss: 1.8809
# Epoch 45/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.1981 - val_loss: 1.8920
# Epoch 46/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.1760 - val_loss: 1.8955
# Epoch 47/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.1598 - val_loss: 1.8935
# Epoch 48/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.1258 - val_loss: 1.8930
# Epoch 49/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.0981 - val_loss: 1.8976
# Epoch 50/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.1373 - val_loss: 1.9715
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step
# Reloading Tuner from my_dir_2_7\NOx_prediction\tuner0.json
# Epoch 1/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 12s 10ms/step - loss: 2.0603 - val_loss: 1.8286
# Epoch 2/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6546 - val_loss: 2.0903
# Epoch 3/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8379 - val_loss: 1.8002
# Epoch 4/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6461 - val_loss: 2.0478
# Epoch 5/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5857 - val_loss: 1.9333
# Epoch 6/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6671 - val_loss: 1.7835
# Epoch 7/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5664 - val_loss: 1.7315
# Epoch 8/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8478 - val_loss: 1.8419
# Epoch 9/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5307 - val_loss: 1.7304
# Epoch 10/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.5522 - val_loss: 1.7150
# Epoch 11/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4663 - val_loss: 1.7956
# Epoch 12/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4007 - val_loss: 1.7797
# Epoch 13/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4462 - val_loss: 1.7546
# Epoch 14/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.4587 - val_loss: 1.9697
# Epoch 15/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.3293 - val_loss: 1.8096
# Epoch 16/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3399 - val_loss: 1.9232
# Epoch 17/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3251 - val_loss: 1.9554
# Epoch 18/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3628 - val_loss: 1.9348
# Epoch 19/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2465 - val_loss: 1.9790
# Epoch 20/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2073 - val_loss: 1.9068
# Epoch 21/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1856 - val_loss: 1.9620
# Epoch 22/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2291 - val_loss: 1.9690
# Epoch 23/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0802 - val_loss: 1.9013
# Epoch 24/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0867 - val_loss: 1.9579
# Epoch 25/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0537 - val_loss: 1.9763
# Epoch 26/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9232 - val_loss: 2.0894
# Epoch 27/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9139 - val_loss: 2.1005
# Epoch 28/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9514 - val_loss: 1.8299
# Epoch 29/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9036 - val_loss: 1.9083
# Epoch 30/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8287 - val_loss: 2.1050
# Epoch 31/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7808 - val_loss: 2.2069
# Epoch 32/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7890 - val_loss: 2.1178
# Epoch 33/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7271 - val_loss: 2.0671
# Epoch 34/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7608 - val_loss: 2.0115
# Epoch 35/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6892 - val_loss: 2.1057
# Epoch 36/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7353 - val_loss: 2.1099
# Epoch 37/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6391 - val_loss: 2.1279
# Epoch 38/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6287 - val_loss: 2.1011
# Epoch 39/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5881 - val_loss: 2.0941
# Epoch 40/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5805 - val_loss: 2.1268
# Epoch 41/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5408 - val_loss: 2.1062
# Epoch 42/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5423 - val_loss: 2.1030
# Epoch 43/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5573 - val_loss: 2.1393
# Epoch 44/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4916 - val_loss: 2.1590
# Epoch 45/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4679 - val_loss: 2.1938
# Epoch 46/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4540 - val_loss: 2.1282
# Epoch 47/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5003 - val_loss: 2.1441
# Epoch 48/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5086 - val_loss: 2.1249
# Epoch 49/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5448 - val_loss: 2.1269
# Epoch 50/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4494 - val_loss: 2.1391
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# Reloading Tuner from my_dir_3_7\NOx_prediction\tuner0.json
# Epoch 1/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 2.1852 - val_loss: 1.8330
# Epoch 2/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.6105 - val_loss: 1.7444
# Epoch 3/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6827 - val_loss: 1.7634
# Epoch 4/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.7089 - val_loss: 1.7614
# Epoch 5/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.6393 - val_loss: 1.7508
# Epoch 6/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.5492 - val_loss: 1.8519
# Epoch 7/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.6081 - val_loss: 1.7215
# Epoch 8/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.5756 - val_loss: 1.7528
# Epoch 9/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.6449 - val_loss: 1.7854
# Epoch 10/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.5137 - val_loss: 1.7606
# Epoch 11/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.4129 - val_loss: 1.7537
# Epoch 12/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4906 - val_loss: 1.6965
# Epoch 13/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.5167 - val_loss: 1.6680
# Epoch 14/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.4419 - val_loss: 1.7625
# Epoch 15/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.3354 - val_loss: 1.6553
# Epoch 16/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.3206 - val_loss: 1.6538
# Epoch 17/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.2623 - val_loss: 1.6529
# Epoch 18/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.3437 - val_loss: 1.7192
# Epoch 19/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.2770 - val_loss: 1.7892
# Epoch 20/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.2359 - val_loss: 1.6900
# Epoch 21/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 1.1522 - val_loss: 1.5972
# Epoch 22/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.1360 - val_loss: 1.7126
# Epoch 23/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1.0874 - val_loss: 1.6213
# Epoch 24/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9827 - val_loss: 1.6290
# Epoch 25/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1.0422 - val_loss: 1.6566
# Epoch 26/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9986 - val_loss: 1.7699
# Epoch 27/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.9388 - val_loss: 1.6477
# Epoch 28/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.8824 - val_loss: 1.7407
# Epoch 29/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.9123 - val_loss: 1.6745
# Epoch 30/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.8580 - val_loss: 1.5988
# Epoch 31/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.8019 - val_loss: 1.7014
# Epoch 32/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.8251 - val_loss: 1.7566
# Epoch 33/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.7616 - val_loss: 1.7100
# Epoch 34/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.7423 - val_loss: 1.8335
# Epoch 35/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.7646 - val_loss: 1.6627
# Epoch 36/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.7201 - val_loss: 1.7952
# Epoch 37/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.6738 - val_loss: 1.7302
# Epoch 38/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.6682 - val_loss: 1.7829
# Epoch 39/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.5919 - val_loss: 1.8084
# Epoch 40/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.6223 - val_loss: 1.8363
# Epoch 41/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5544 - val_loss: 1.7757
# Epoch 42/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5527 - val_loss: 1.7803
# Epoch 43/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.5662 - val_loss: 1.8199
# Epoch 44/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.5292 - val_loss: 1.9001
# Epoch 45/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4938 - val_loss: 1.8646
# Epoch 46/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4808 - val_loss: 1.8913
# Epoch 47/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4985 - val_loss: 1.9019
# Epoch 48/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.4562 - val_loss: 1.8698
# Epoch 49/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.4322 - val_loss: 1.8914
# Epoch 50/50
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.4101 - val_loss: 1.9754
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step
# LSTM Model Results:
# Time steps: 1, Forecast days: 7
# Test Loss: 1.7310912609100342
# Test MAE: 0.8529440942660419
# Test RMSE: 1.317224046325222
#
# Time steps: 1, Forecast days: 10
# Test Loss: 1.722333312034607
# Test MAE: 0.8157873065902397
# Test RMSE: 1.3045336284435947
#
# Time steps: 2, Forecast days: 7
# Test Loss: 1.9912062883377075
# Test MAE: 0.8761077450220959
# Test RMSE: 1.413137556022494
#
# Time steps: 2, Forecast days: 10
# Test Loss: 2.3447046279907227
# Test MAE: 0.8678283824033255
# Test RMSE: 1.3887258198099628
#
# Time steps: 3, Forecast days: 7
# Test Loss: 1.8904106616973877
# Test MAE: 0.8419301925816313
# Test RMSE: 1.377846219827762
#
# Time steps: 3, Forecast days: 10
# Test Loss: 1.84917414188385
# Test MAE: 0.8347186054688178
# Test RMSE: 1.342818341256401
#
# Time steps: 4, Forecast days: 7
# Test Loss: 1.583907127380371
# Test MAE: 0.7815910963229407
# Test RMSE: 1.2462914476901266
#
# Linear Regression Model Results:
# Test MAE: 0.841450977374939
# Test RMSE: 1.2874023847392522
#
# Feature Importance Analysis:
# Feature: HDD, Importance: 3.0253837230010117
# Feature: PP, Importance: 0.6673390945205058
# Feature: VP, Importance: 0.4858144050164864
# Feature: TV, Importance: 0.3943591056814229
# Feature: Tmean, Importance: 0.20866030393349652
# Feature: WS, Importance: 0.19602659921202137
# Feature: meanRH, Importance: 0.19405211193320157
# Feature: WG, Importance: 0.16651294193456864
# Feature: SD, Importance: 0.07426113118024107
# Independent T-Test Results
# T-Statistic: -0.5086340770512463
# P-Value: 0.632650342170727
# ANOVA Test Results
# F-Statistic: 4.740360158472536
# P-Value: 0.1167689657600352
#
# Policy Recommendations:
# 2. Based on feature importance, focus on improving conditions related to the most important features:
# - HDD: Implement measures to reduce or control the impact of HDD.
# - PP: Implement measures to reduce or control the impact of PP.
# - VP: Implement measures to reduce or control the impact of VP.
# - TV: Implement measures to reduce or control the impact of TV.
# - Tmean: Implement measures to reduce or control the impact of Tmean.
# 3. Consider implementing policies that address the factors contributing to NOx emissions, as indicated by the features with high importance scores, to reduce overall pollution levels.
